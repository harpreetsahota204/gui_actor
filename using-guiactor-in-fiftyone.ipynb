# %% [markdown]
# # Using GUI Actor in FiftyOne
#
# This tutorial demonstrates how to use the GUI-Actor vision-language models with FiftyOne for various visual understanding tasks.
#
# ## Load a Sample Dataset
#
# First, let's load a UI dataset from the [FiftyOne Hugging Face Org](https://huggingface.co/Voxel51).

# %%
import fiftyone as fo
from fiftyone.utils.huggingface import load_from_hub

# Load 5 random samples from the WaveUI dataset
dataset = load_from_hub(
    "Voxel51/ScreenSpot-v2",
    shuffle=True,
    overwrite=True,
    max_samples=100 # you can take just a subset of the data if you'd like
)
# Out:
# Downloading config file fiftyone.yml from Voxel51/ScreenSpot-v2
# Loading dataset
# Importing samples...
#  100% |█████████████████| 100/100 [3.8ms elapsed, 0s remaining, 26.0K samples/s]

# %% [markdown]
# Launch the FiftyOne App to visualize the dataset (optional)

# %%
fo.launch_app(dataset)

# %% [markdown]
# Take a look at the first sample and instruction to get a sense of what is in the dataset:

# %%
from PIL import Image

Image.open(dataset.first().filepath)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2360x1640>

# %%
dataset.first().instruction
# Out:
# 'check the weather'

# %% [markdown]
# ## Set Up GUI-Actor Integration
#
# Register the GUI-Actor remote zoo model source and load the model.

# %%
import fiftyone.zoo as foz

# Register the model source
foz.register_zoo_model_source("https://github.com/harpreetsahota204/gui_actor", overwrite=True)
# Out:
# Downloading https://github.com/harpreetsahota204/gui_actor...
#   226.9Kb [49.9ms elapsed, ? remaining, 4.4Mb/s]
# Overwriting existing model source '/home/harpreet/fiftyone/__models__/GUI-Actor'

# %% [markdown]
# # Load the `GUI-Actor-7B-Qwen2.5-VL` model
#
# You can also use `GUI-Actor-3B-Qwen2.5-VL`

# %%
model = foz.load_zoo_model(
    "microsoft/GUI-Actor-7B-Qwen2.5-VL",
    # install_requirements=True, #you can pass this to make sure you have all reqs installed
    )

# %%
dataset.apply_model(
    model, 
    prompt_field="instruction", 
    label_field="guiactor_output"
    )
# Out:
#  100% |█████████████████| 100/100 [2.4m elapsed, 0s remaining, 0.7 samples/s]

# %% [markdown]
# #### Adding Attention Heatmaps to Dataset
#
# Since FiftyOne models can only return one prediction type (`keypoints` in our case), we save the attention heatmaps as PNG files during inference and need to manually link them back to the dataset.
#
# This allows us to visualize both the predicted interaction points and the model's attention patterns together in the FiftyOne app.

# %%
from pathlib import Path 

for sample in dataset:
    # Generate expected heatmap path
    original_path = Path(sample.filepath)
    heatmap_path = original_path.parent / f"{original_path.stem}_attention.png"
    
    if heatmap_path.exists():
        # Add heatmap field using the saved PNG file
        sample["attention_heatmap"] = fo.Heatmap(map_path=str(heatmap_path))
        sample.save()
    else:
        print(f"Heatmap not found for {sample.filepath}")

# %% [markdown]
# Take a look at the first Sample to ensure we have parsed the output:

# %%
dataset.first()
# Out:
# <Sample: {
#     'id': '685c3b70a40806dae7c6b310',
#     'media_type': 'image',
#     'filepath': '/home/harpreet/fiftyone/huggingface/hub/Voxel51/ScreenSpot-v2/data/mobile_1ca5b944-293a-46a1-af95-eb35bc8a0b2a_0.png',
#     'tags': [],
#     'metadata': <ImageMetadata: {
#         'size_bytes': 3262770,
#         'mime_type': 'image/png',
#         'width': 2360,
#         'height': 1640,
#         'num_channels': 3,
#     }>,
#     'created_at': datetime.datetime(2025, 6, 25, 20, 21, 40, 364000),
#     'last_modified_at': datetime.datetime(2025, 6, 25, 20, 26, 47, 466000),
#     'instruction': 'check the weather',
#     'data_source': <Classification: {
#         'id': '685c3b6fa40806dae7c6a921',
#         'tags': [],
#         'label': 'ios',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'action_detection': <Detection: {
#         'id': '685c3b6fa40806dae7c6a920',
#         'attributes': {},
#         'tags': [],
#         'label': 'icon',
#         'bounding_box': [
#             0.09449152542372881,
#             0.0475609756097561,
#             0.25466101694915255,
#             0.3615853658536585,
#         ],
#         'mask': None,
#         'mask_path': None,
#         'confidence': None,
#         'index': None,
#     }>,
#     'guiactor_output': <Keypoints: {
#         'keypoints': [
#             <Keypoint: {
#                 'id': '685c5af568467dad0a71eed1',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'top_interaction_point',
#                 'points': [[0.1534771776171048, 0.1580132356266739]],
#                 'confidence': [0.0028829574584960938],
#                 'index': None,
#                 'reasoning': '<|diff_marker|>',
#             }>,
#         ],
#     }>,
#     'attention_heatmap': <Heatmap: {
#         'id': '685c5b8768467dad0a71ef35',
#         'tags': [],
#         'map': None,
#         'map_path': '/home/harpreet/fiftyone/huggingface/hub/Voxel51/ScreenSpot-v2/data/mobile_1ca5b944-293a-46a1-af95-eb35bc8a0b2a_0_attention.png',
#         'range': None,
#     }>,
# }>

# %%
# Visualize all results in the FiftyOne App
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-be34e88a-0908-4a93-8d6c-109be96e8788 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-be34e88a-0908-4a93-8d6c-109be96e8788 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-be34e88a-0908-4a93-8d6c-109be96e8788:focus {
#   outline: none;
# }
# #fooverlay-be34e88a-0908-4a93-8d6c-109be96e8788 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-be34e88a-0908-4a93-8d6c-109be96e8788">
#    <div id="fooverlay-be34e88a-0908-4a93-8d6c-109be96e8788" style="display: none;">
#       <button id="foactivate-be34e88a-0908-4a93-8d6c-109be96e8788" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 2968px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-be34e88a-0908-4a93-8d6c-109be96e8788");
#      var overlay = document.getElementById("fooverlay-be34e88a-0908-4a93-8d6c-109be96e8788");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "be34e88a-0908-4a93-8d6c-109be96e8788" },
#               subscription: "be34e88a-0908-4a93-8d6c-109be96e8788"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
session.freeze()
